# %% [markdown]
# <b>Tout d'abord il faut importer les librairies dont j'ai besoin pour prepocessing mes données <b>
# <hr />

# %% [markdown]
# !pip install langdetect

# %%
import pandas as pd
import numpy as np
#Pour tokenisation et normalisation les corpus
import nltk
from nltk import *
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.tag.stanford import StanfordPOSTagger
from nltk import StanfordTagger
#Detecteur lanquage du text
from langdetect import detect
import time
import re
import string
import spacy
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop
from spacy.lang.en.stop_words import STOP_WORDS as en_stop
#Pour clustering les annonces
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# <b>Les Fonctionnes:<b>
# <hr />

# %%
#1# "normalisationCorpus" est une fonctionne qui va ajouter la colonne 'phrase_token' qui contiendra le nom
#de metier et sa description en miniscule
#et trois colonnes vides 'phrases_cible', 'resume' et 'category' afin d'être utiliser dans le preprocessing

def normalisationCorpus(df):
    donnees = df
    corpus = ""
    donnees['phrase_token']=""
    for index, row in donnees.iterrows():
        donnees.loc[index,'entreprise'] = str(donnees.loc[index,'entreprise'])
        corpus = "titre " +donnees.loc[index,'metier'].lower() +". "+ "sommaire "+donnees.loc[index,'sommaire'].lower()+". "+ donnees.loc[index,'description'].lower() +"."
        donnees.loc[index,'phrase_token'] = sent_tokenize(corpus)
    donnees['phrases_cible']=""
    donnees['resume']=""
    donnees['category'] = ""
    return donnees

#2# langueDetecte est une fonctionne qui va detecter les annonces anglais et puis il les supprimes

def langueDetecte(df):
    #count = 0
    donnees = df
    for index, row in donnees.iterrows():
        lang = detect(donnees.loc[index,'description'])
        if lang == "en" :
            #count+=1
            donnees = donnees.drop(index)
    #print(count)
    return donnees

#3# "nettoayage" est une fonctionne afin de chercher quelques mots ciblés qui peuvent contenir les compétences

def nettoayage(df):
    donnees = df
    collect=""
    corpus = ""
    mots_cible=["expérience","profil","compétence","mission","mont","capacité","dispos","maitris","titre","sommaire"]
    for index, row in donnees.iterrows():
        corpus = donnees.loc[index,"phrase_token"]
        for phrase in corpus:
            if any(mot in phrase for mot in mots_cible):
                collect = collect +" " + phrase + " \n"
        #Ici pour je supprime de mon corpus tous les mots cible dans la variable mots_cible
        mots = collect.split()

        motsResultat  = [mot for mot in mots if mot.lower() not in mots_cible]
        resultat = ' '.join(motsResultat)
        donnees.loc[index,"phrases_cible"] = resultat
        collect = ""
        
    return donnees

#4# "stopMots" est une fonctionne qui va supprimmer les mots frequants comme (de,le,la,je,avec,...)
#dans le corpus pour qu'il soit plus propre pour l'étape de machine learning

def stopMots(df):
    corpus = ""
    sans=""
    monList = ['de','et','vous','des','à','la','en','les','sur','vos','le','leur','',"l'",'pour','avec','êtes','votre','chaque','est','sont','du','ils','leurs','que','par','un','une','revenus','première',]
    stopWords = list(stopwords.words('french'))+list(fr_stop) + list(en_stop)+monList
    donnees = df
    transl_table = dict( [ (ord(x), ord(y)) for x,y in zip( u"‘'’´“”–-",  u"''''\"\"--") ] )
    for index, row in donnees.iterrows():
        corpus = donnees.loc[index,"phrases_cible"].replace("d'"," ").replace("l'"," ")
        corpus = corpus.translate(transl_table)
        corpus = corpus.translate(str.maketrans('','',string.punctuation)).replace("’"," ").replace("'"," ")
        tokens = word_tokenize(corpus, language='french')
        for token in tokens:
            if token not in stopWords :
                sans = sans + " " + token+ " "
        donnees.loc[index,"resume"] = sans
        sans = ""
    return donnees

# %% [markdown]
# #IMPORTATION LES DONNEES
# <hr />

# %%
mainDataFrame = pd.read_csv("annonces.csv")

# %% [markdown]
# #PREMIERE VUE DE MES DONNEES
# <hr />

# %%
mainDataFrame.head(5)
# Out:
#    id         motcle                             metier            entreprise  \
# 0   1  data analyste               Stage Chef de Projet  Animaux Vie et Santé
# 1   2  data analyste  Data Analyst Etudes Marketing H/F          Leroy Merlin
# 2   3  data analyste        Data Analyst / Engineer H/F        AMD Consulting
# 3   4  data analyste        Un(e) Data Analyst F/H (IT)                 CELAD
# 4   5  data analyste                       Data Analyst              Strathom
#
#                  location              datedannoce  \
# 0          Wasquehal (59)  Il y a plus de 30 jours
# 1              Lille (59)  Il y a plus de 30 jours
# 2              Lille (59)  Il y a plus de 30 jours
# 3              Lille (59)  Il y a plus de 30 jours
# 4  Villeneuve-d'Ascq (59)          il y a 18 jours
#
#                                                 lien  \
# 0  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4  https://fr.indeed.com/rc/clk?jk=6dc1f78291259d...
#
#                                             sommaire  \
# 0  Animaux Vie et Santé est une petite filiale de...
# 1  En s’appuyant sur des organisations disruptive...
# 2  Contexte de la missionL'équipe Performance Eco...
# 3  Dans le domaine de la Grande Distribution, nou...
# 4  Data analyst, DataViz, Informatique, Modélisat...
#
#                                          description
# 0  Offre : Stage de 6 mois, à partir de janvier 2...
# 1  Qui sommes-nous ? \n Face à un marché de plus ...
# 2  AMD consulting, est un acteur reconnu dans le ...
# 3  Dans le domaine de la Grande Distribution, nou...
# 4  data analyst, DataViz, Informatique, Modélisat...

# %%
mainDataFrame.tail(5)
# Out:
#         id motcle                                             metier  \
# 1883  1884     js  Développement front-end/back-end de statistiqu...
# 1884  1885     js               Développeur Fullstack Confirmé (H/F)
# 1885  1886     js             Architecte Technique (F/H) / Freelance
# 1886  1887     js         Développeur Drupal 8 Fullstack / Freelance
# 1887  1888     js  Ingénieur Etude et Développement Front-End Jav...
#
#          entreprise      location              datedannoce  \
# 1883      Worldline   Seclin (59)  Il y a plus de 30 jours
# 1884  Ineat Conseil    Lille (59)  Il y a plus de 30 jours
# 1885        IZYFREE    Lille (59)  Il y a plus de 30 jours
# 1886      GROUPE HN    Lille (59)  Il y a plus de 30 jours
# 1887         Nextoo  Roubaix (59)  Il y a plus de 30 jours
#
#                                                    lien  \
# 1883  https://fr.indeed.com/rc/clk?jk=6a934db76c855c...
# 1884  https://fr.indeed.com/rc/clk?jk=4fa90d04e4e5dc...
# 1885  https://fr.indeed.com/rc/clk?jk=3afd8bc077cf18...
# 1886  https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1887  https://fr.indeed.com/rc/clk?jk=13c2c5f55dccfa...
#
#                                                sommaire  \
# 1883  Worldline [Euronext: WLN] is the European lead...
# 1884  Découvrez une organisation qui vous donne les ...
# 1885  Votre mission consistera à: - Accompagner le d...
# 1886  Au sein d’une équipe pluridisciplinaire vous p...
# 1887  Chez nos clients ou au sein de notre Centre De...
#
#                                             description
# 1883  About Worldline \n Worldline [Euronext: WLN] i...
# 1884  Contrat :  CDI \n \nDisponibilité :  ASAP \n \...
# 1885  Votre mission consistera à:  - Accompagner le ...
# 1886  Au sein d’une équipe pluridisciplinaire vous p...
# 1887  Chez nos clients ou au sein de notre Centre De...

# %%
mainDataFrame.shape
# Out:
# (1888, 9)

# %% [markdown]
# <b>Mon dataset contien 1888 LIGNES ET 9 COLONNES</b>

# %%
(mainDataFrame.loc[:,"description"].isnull() == False).count()
# Out:
# 1888

# %% [markdown]
# <b>Et il n'y a pas de champs vide dans la colonne description</b>

# %% [markdown]
# <br />
# <b> NETTOYAGE : </b>
# <hr />

# %%
#dans mon data set Il y avait 71 annonces en anglais qu'il faut être supprimé
#Supprimer les annonce en Anglais
mainDataFrame = langueDetecte(mainDataFrame)

#je veux mettre id comme l'index de mon dataframe
mainDataFrame = mainDataFrame.set_index('id')

#Supprimer les dedoublons
mainDataFrame = mainDataFrame.drop_duplicates(subset='lien', keep="first")

#Normalisation à l'aide de la fonction "normalisationCorpus"
mainDataFrame = normalisationCorpus(mainDataFrame)

#Nettoayage les corpus à l'aide de la fonction "nettoayage"
mainDataFrame = nettoayage(mainDataFrame)

#Supprimer les mots frequants à l'aide de la fonction "stopMots"
mainDataFrame = stopMots(mainDataFrame)
# Out:
# 71

# %%
mainDataFrame.head(5)
# Out:
#            motcle                             metier            entreprise  \
# id
# 1   data analyste               Stage Chef de Projet  Animaux Vie et Santé
# 2   data analyste  Data Analyst Etudes Marketing H/F          Leroy Merlin
# 3   data analyste        Data Analyst / Engineer H/F        AMD Consulting
# 4   data analyste        Un(e) Data Analyst F/H (IT)                 CELAD
# 5   data analyste                       Data Analyst              Strathom
#
#                   location              datedannoce  \
# id
# 1           Wasquehal (59)  Il y a plus de 30 jours
# 2               Lille (59)  Il y a plus de 30 jours
# 3               Lille (59)  Il y a plus de 30 jours
# 4               Lille (59)  Il y a plus de 30 jours
# 5   Villeneuve-d'Ascq (59)          il y a 18 jours
#
#                                                  lien  \
# id
# 1   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 5   https://fr.indeed.com/rc/clk?jk=6dc1f78291259d...
#
#                                              sommaire  \
# id
# 1   Animaux Vie et Santé est une petite filiale de...
# 2   En s’appuyant sur des organisations disruptive...
# 3   Contexte de la missionL'équipe Performance Eco...
# 4   Dans le domaine de la Grande Distribution, nou...
# 5   Data analyst, DataViz, Informatique, Modélisat...
#
#                                           description  \
# id
# 1   Offre : Stage de 6 mois, à partir de janvier 2...
# 2   Qui sommes-nous ? \n Face à un marché de plus ...
# 3   AMD consulting, est un acteur reconnu dans le ...
# 4   Dans le domaine de la Grande Distribution, nou...
# 5   data analyst, DataViz, Informatique, Modélisat...
#
#                                          phrase_token  \
# id
# 1   [titre stage chef de projet., sommaire animaux...
# 2   [titre data analyst etudes marketing h/f., som...
# 3   [titre data analyst / engineer h/f., sommaire ...
# 4   [titre un(e) data analyst f/h (it)., sommaire ...
# 5   [titre data analyst., sommaire data analyst, d...
#
#                                         phrases_cible  \
# id
# 1   stage chef de projet. animaux vie et santé est...
# 2   data analyst etudes marketing h/f. en s’appuya...
# 3   data analyst / engineer h/f. contexte de la mi...
# 4   un(e) data analyst f/h (it). dans le domaine d...
# 5   data analyst. data analyst, dataviz, informati...
#
#                                                resume category
# id
# 1    stage  chef  projet  animaux  vie  santé  pet...
# 2    data  analyst  etudes  marketing  hf  sappuya...
# 3    data  analyst  engineer  hf  contexte  missio...
# 4    data  analyst  fh  domaine  grande  distribut...
# 5    data  analyst  data  analyst  dataviz  inform...

# %% [markdown]
# <b>TESTING</b>
# <hr />

# %% [markdown]
# <b>TF-IDF</b>
# <hr />
# <p>TF-IDF signifie "Term Frequency - Inverse Document Frequency".<br />
# C'est une technique pour quantifier un mot dans les documents,
# nous calculons généralement un poids à chaque mot qui signifie
# l'importance du mot dans le document et le corpus.     <br />
# Cette méthode est une technique largement utilisée dans la
#     recherche d'informations et l'exploration de textes.</p>
# <hr />

# %%
# CRÉER UN VARIABLE TTfidfVectorizer 
tfv = TfidfVectorizer(ngram_range = (1,1))

#TRANSFORMEZ LA COLONNE RESUME AU FORMAT VECTEUR DE POIDS
vec_text = tfv.fit_transform(mainDataFrame.loc[:,"resume"])

#Retourner une liste des mots fréquants.
words = tfv.get_feature_names()

# %%
# CONFIGURATION LE CLUSTERING AVEC KMEAN
kmeans = KMeans(n_clusters = 20, n_init = 17, n_jobs = -1, tol = 0.01, max_iter = 200)
# FIT LES DONNÉES AVEC LA VECTEUR vec_text
kmeans.fit(vec_text)
# Transformer les nombres aux mots correspondants
#common_words = kmeans.cluster_centers_.argsort()[:,-1:-11:-1]
#for num, centroid in enumerate(common_words):
#    print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))
# Out:
# /home/negar/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:938: FutureWarning: 'n_jobs' was deprecated in version 0.23 and will be removed in 0.25.
#   warnings.warn("'n_jobs' was deprecated in version 0.23 and will be"
# 0 : développeur, js, react, stack, conseil, nodejs, freelance, node, recherche, consistera
# 1 : informatique, technicien, support, utilisateurs, informatiques, incidents, windows, réseaux, systèmes, gestion
# 2 : web, développement, développeur, net, projets, applications, compétences, projet, missions, technique
# 3 : data, données, analyst, big, engineer, accompagner, compétences, analyse, retail, business
# 4 : espacefreelance, directs, indépendants, consultants, lun, réseau, recherche, régie, hf, pourvoir
# 5 : téléphonie, description, progresser, activités, 3500, plusieurs, assurées, informatique, répartis, bagage
# 6 : sécurité, réseaux, réseau, systèmes, ingénieur, informatique, compétences, système, infrastructures, dune
# 7 : communication, startup, mode, valeur, possèdes, mois, faire, responsable, optimises, vs
# 8 : prime, vacances, ticket, salle, prévoyance, de, restaurant, mutuelle, analyste, participation
# 9 : technicienne, cloud, expérimentée, capacités, installer, infrastructures, souhaité, offrons, épanouir, démontrer
# 10 : marketing, projet, chef, clients, hf, poste, formation, ecommerce, client, gestion
# 11 : horaires, travail, ans, flexibles, 00000, souhaité, télétravail, temps, cdi, emploi
# 12 : devras, compétences, mettre, bon, qualités, désirées, relever, cse, sii, fungenieur
# 13 : java, développement, devops, spring, angular, compétences, technologies, techniques, tests, nodejs
# 14 : gestion, annexes, maintenance, informatique, parc, serveurs, 00000, dau, linux, chef
# 15 : stage, mois, seo, communication, marketing, durée, sociaux, référencement, rédacteur, contenus
# 16 : cloud, devops, azure, compétences, aws, google, terraform, système, gcp, public
# 17 : consultant, etl, problématiques, data, relationnelles, urbaniste, leader, talend, team, équipe
# 18 : concevoir, langages, code, dépendances, matérielle, kanban, configurer, linfrastructure, java, interroger
# 19 : celery, restauration, incident, rapide, redis, haut, cas, disponibilité, kafka, principale

# %%
#Associer chaque annonce au son cluster correspondant
mainDataFrame['category'] = kmeans.labels_

# %%
#Voir le resultat
mainDataFrame.head(5)
# Out:
#            motcle                             metier            entreprise  \
# id
# 1   data analyste               Stage Chef de Projet  Animaux Vie et Santé
# 2   data analyste  Data Analyst Etudes Marketing H/F          Leroy Merlin
# 3   data analyste        Data Analyst / Engineer H/F        AMD Consulting
# 4   data analyste        Un(e) Data Analyst F/H (IT)                 CELAD
# 5   data analyste                       Data Analyst              Strathom
#
#                   location              datedannoce  \
# id
# 1           Wasquehal (59)  Il y a plus de 30 jours
# 2               Lille (59)  Il y a plus de 30 jours
# 3               Lille (59)  Il y a plus de 30 jours
# 4               Lille (59)  Il y a plus de 30 jours
# 5   Villeneuve-d'Ascq (59)          il y a 18 jours
#
#                                                  lien  \
# id
# 1   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4   https://fr.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 5   https://fr.indeed.com/rc/clk?jk=6dc1f78291259d...
#
#                                              sommaire  \
# id
# 1   Animaux Vie et Santé est une petite filiale de...
# 2   En s’appuyant sur des organisations disruptive...
# 3   Contexte de la missionL'équipe Performance Eco...
# 4   Dans le domaine de la Grande Distribution, nou...
# 5   Data analyst, DataViz, Informatique, Modélisat...
#
#                                           description  \
# id
# 1   Offre : Stage de 6 mois, à partir de janvier 2...
# 2   Qui sommes-nous ? \n Face à un marché de plus ...
# 3   AMD consulting, est un acteur reconnu dans le ...
# 4   Dans le domaine de la Grande Distribution, nou...
# 5   data analyst, DataViz, Informatique, Modélisat...
#
#                                          phrase_token  \
# id
# 1   [titre stage chef de projet., sommaire animaux...
# 2   [titre data analyst etudes marketing h/f., som...
# 3   [titre data analyst / engineer h/f., sommaire ...
# 4   [titre un(e) data analyst f/h (it)., sommaire ...
# 5   [titre data analyst., sommaire data analyst, d...
#
#                                         phrases_cible  \
# id
# 1   stage chef de projet. animaux vie et santé est...
# 2   data analyst etudes marketing h/f. en s’appuya...
# 3   data analyst / engineer h/f. contexte de la mi...
# 4   un(e) data analyst f/h (it). dans le domaine d...
# 5   data analyst. data analyst, dataviz, informati...
#
#                                                resume  category
# id
# 1    stage  chef  projet  animaux  vie  santé  pet...        15
# 2    data  analyst  etudes  marketing  hf  sappuya...         3
# 3    data  analyst  engineer  hf  contexte  missio...         3
# 4    data  analyst  fh  domaine  grande  distribut...         3
# 5    data  analyst  data  analyst  dataviz  inform...         3

# %%
#Exporter les données traitées finales
mainDataFrame.to_csv('final.csv',header=True)
